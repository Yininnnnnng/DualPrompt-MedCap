# %%
#===tag2text with rad========

# %%
from google.colab import drive
drive.mount('/content/drive')
import io
import sys
import os
import json
import torch
from PIL import Image
import pandas as pd
from tqdm.notebook import tqdm


sys.path.append('/content/drive/MyDrive/PhD/Research1/recognize-anything-main')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
try:
    from ram.models import tag2text
    from ram import get_transform
    print("Successfully imported tag2text from Google Drive")
except ImportError as e:
    print(f"Error importing from Google Drive: {e}")
    print("Falling back to cloning the repository in Colab's local filesystem")
    # !git clone https://github.com/xinyu1205/recognize-anything.git /content/recognize-anything
    # %cd /content/recognize-anything
    # !pip install -e .
    # %cd /content
    sys.path.append('/content/recognize-anything')
    from ram.models import tag2text
    from ram import get_transform
# Out:
# Error importing from Google Drive: No module named 'timm'
# Falling back to cloning the repository in Colab's local filesystem
# Cloning into '/content/recognize-anything'...
# remote: Enumerating objects: 737, done.
# remote: Counting objects: 100% (447/447), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 737 (delta 310), reused 290 (delta 224), pack-reused 290 (from 1)
# Receiving objects: 100% (737/737), 27.14 MiB | 24.14 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# /content/recognize-anything
# Obtaining file:///content/recognize-anything
#   Preparing metadata (setup.py) ... done
# Collecting clip@ git+https://github.com/openai/CLIP.git (from ram==0.0.1)
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-install-xvwk44zd/clip_818c47fbc2474fb6a792c08071d16b03
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-xvwk44zd/clip_818c47fbc2474fb6a792c08071d16b03
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Collecting timm==0.4.12 (from ram==0.0.1)
#   Downloading timm-0.4.12-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from ram==0.0.1) (4.44.2)
# Collecting fairscale==0.4.4 (from ram==0.0.1)
#   Downloading fairscale-0.4.4.tar.gz (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 10.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pycocoevalcap (from ram==0.0.1)
#   Downloading pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from ram==0.0.1) (2.4.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from ram==0.0.1) (0.19.1+cu121)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from ram==0.0.1) (10.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ram==0.0.1) (1.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->ram==0.0.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->ram==0.0.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->ram==0.0.1) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->ram==0.0.1) (3.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->ram==0.0.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->ram==0.0.1) (2024.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->ram==0.0.1) (4.66.5)
# Collecting ftfy (from clip@ git+https://github.com/openai/CLIP.git->ram==0.0.1)
#   Downloading ftfy-6.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pycocoevalcap->ram==0.0.1) (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (3.7.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->clip@ git+https://github.com/openai/CLIP.git->ram==0.0.1) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->ram==0.0.1) (3.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->ram==0.0.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->ram==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->ram==0.0.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->ram==0.0.1) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->ram==0.0.1) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (1.16.0)
# Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 26.6 MB/s eta 0:00:00
# Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 21.9 MB/s eta 0:00:00
# Downloading ftfy-6.3.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.0 MB/s eta 0:00:00
# Building wheels for collected packages: fairscale, clip
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.4-py3-none-any.whl size=292831 sha256=8aabdafc4290973cd5cd87f100d8bb9e35258f327a6a94c14a7ae6722bb2f6bc
#   Stored in directory: /root/.cache/pip/wheels/08/58/6f/56c57fa8315eb0bcf0287b580c850845be5f116359b809e9f1
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=a3941b7d90f432cd4d42ca1a23fdf37d9a7bc3ba41bc0cae8379f0b6bbc573d5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_xefri2f/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built fairscale clip
# Installing collected packages: ftfy, fairscale, timm, pycocoevalcap, clip, ram
#   Running setup.py develop for ram
# Successfully installed clip-1.0 fairscale-0.4.4 ftfy-6.3.0 pycocoevalcap-1.2 ram-0.0.1 timm-0.4.12
# /content
# /usr/local/lib/python3.10/dist-packages/fairscale/experimental/nn/offload.py:19: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   return torch.cuda.amp.custom_fwd(orig_func)  # type: ignore
# /usr/local/lib/python3.10/dist-packages/fairscale/experimental/nn/offload.py:30: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   return torch.cuda.amp.custom_bwd(orig_func)  # type: ignore

# %%
global_models = {}

def load_models():
    if 'tag2text' not in global_models:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {device}")


        delete_tag_index = [127, 2961, 3351, 3265, 3338, 3355, 3359]
        global_models['tag2text'] = tag2text(pretrained="/content/drive/MyDrive/PhD/Research1/recognize-anything-main/pretrained/tag2text_swin_14m.pth",
                                             image_size=384,
                                             vit='swin_b',
                                             delete_tag_index=delete_tag_index)
        global_models['tag2text'].threshold = 0.68  # threshold
        global_models['tag2text'].eval()
        global_models['tag2text'] = global_models['tag2text'].to(device)
        print("Tag2Text model loaded successfully")


        global_models['transform'] = get_transform(image_size=384)

def process_image(image_data):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


    if isinstance(image_data, dict):
        image_bytes = image_data['bytes']
    elif isinstance(image_data, str):
        image_bytes = json.loads(image_data)['bytes']
    else:
        image_bytes = image_data
    image_bytes = bytes(image_bytes)
    image = Image.open(io.BytesIO(image_bytes)).convert('RGB')
    print(f"Image size: {image.size}")

    image_tensor = global_models['transform'](image).unsqueeze(0).to(device)

    try:

        with torch.no_grad():
            result = global_models['tag2text'].generate(image_tensor, return_tag_predict=True)

        if isinstance(result, tuple) and len(result) == 2:
            captions, tags = result
            caption = captions[0] if captions else "No caption generated"
        else:
            tags = result[0] if isinstance(result, list) else "No tags generated"
            caption = "No caption generated"


        if isinstance(tags, str):
            tags = tags.split('|')

        print(f"Tag2Text generated tags: {tags}")
        print(f"Tag2Text generated caption: {caption}")

        return tags, caption
    except Exception as e:
        print(f"Error processing image: {e}")
        return [], "Error generating caption"

# %%
def main():

    load_models()


    input_parquet = '/content/drive/MyDrive/PhD/Research1/RADdataset/test-00000-of-00001-e5bc3d208bb4deeb.parquet'
    output_json = '/content/drive/MyDrive/PhD/Research1/RADdataset/processed_data.json'


    df = pd.read_parquet(input_parquet)
    print(f"Loaded {len(df)} rows from the parquet file.")

    results = []


    for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing images"):
        image_data = row['image']
        question = row['question']
        answer = row['answer']

        print(f"\nProcessing image {index}")
        print(f"Question: {question}")

        try:

            tags, tag2text_caption = process_image(image_data)


            result = {
                "index": index,
                "question": question,
                "original_answer": answer,
                "tag2text_caption": tag2text_caption,
                "tags": tags,
                "blip3_caption": None
            }
            results.append(result)
        except Exception as e:
            print(f"Error processing image {index}: {e}")

            results.append({
                "index": index,
                "question": question,
                "original_answer": answer,
                "tag2text_caption": "Error generating caption",
                "tags": [],
                "blip3_caption": None
            })

        print("-" * 50)


    with open(output_json, 'w') as f:
        json.dump(results, f, indent=2)

    print(f"Processing complete. Results saved to {output_json}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# /encoder/layer/0/crossattention/self/query is tied
# /encoder/layer/0/crossattention/self/key is tied
# /encoder/layer/0/crossattention/self/value is tied
# /encoder/layer/0/crossattention/output/dense is tied
# /encoder/layer/0/crossattention/output/LayerNorm is tied
# /encoder/layer/0/intermediate/dense is tied
# /encoder/layer/0/output/dense is tied
# /encoder/layer/0/output/LayerNorm is tied
# /encoder/layer/1/crossattention/self/query is tied
# /encoder/layer/1/crossattention/self/key is tied
# /encoder/layer/1/crossattention/self/value is tied
# /encoder/layer/1/crossattention/output/dense is tied
# /encoder/layer/1/crossattention/output/LayerNorm is tied
# /encoder/layer/1/intermediate/dense is tied
# /encoder/layer/1/output/dense is tied
# /encoder/layer/1/output/LayerNorm is tied
# --------------
# /content/drive/MyDrive/PhD/Research1/recognize-anything-main/pretrained/tag2text_swin_14m.pth
# --------------
# load checkpoint from /content/drive/MyDrive/PhD/Research1/recognize-anything-main/pretrained/tag2text_swin_14m.pth
# vit: swin_b
# Tag2Text model loaded successfully
# Loaded 451 rows from the parquet file.
# Processing images:   0%|          | 0/451 [00:00<?, ?it/s]
# Processing image 0
# Question: is there evidence of an aortic aneurysm?
# Image size: (1024, 1291)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 1
# Question: is there airspace consolidation on the left side?
# Image size: (480, 503)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a broken right middle x ray
# --------------------------------------------------
#
# Processing image 2
# Question: is there any intraparenchymal abnormalities in the lung fields?
# Image size: (1024, 1024)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 3
# Question: which side of the heart border is obscured?
# Image size: (867, 979)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 4
# Question: where are the kidney?
# Image size: (1024, 656)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 5
# Question: are the kidneys present in this image?
# Image size: (1024, 656)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 6
# Question: is the colon more prominent on the patient's right or left side?
# Image size: (708, 514)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 7
# Question: where is the colon most prominent from this view?
# Image size: (708, 514)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 8
# Question: is the heart size in this image smaller or larger than if the image was taken ap?
# Image size: (1024, 1307)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 9
# Question: is the liver visible in the image?
# Image size: (766, 910)
# Tag2Text generated tags: ['image | show']
# Tag2Text generated caption: a ct scan of the abdomen showing the fertilisation of the fertilisation
# --------------------------------------------------
#
# Processing image 10
# Question: is this an axial image?
# Image size: (444, 566)
# Tag2Text generated tags: ['brain | text | image | face']
# Tag2Text generated caption: a computer image of the human brain
# --------------------------------------------------
#
# Processing image 11
# Question: what structures are visible in this image?
# Image size: (444, 566)
# Tag2Text generated tags: ['brain | text | image | face']
# Tag2Text generated caption: a computer image of the human brain
# --------------------------------------------------
#
# Processing image 12
# Question: what is this lucency amid densities in the right lung?
# Image size: (960, 1200)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest x ray
# --------------------------------------------------
#
# Processing image 13
# Question: is there evidence of any abnormalities of the lung parenchyma?
# Image size: (1024, 1024)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 14
# Question: are the temporal bones fractured?
# Image size: (360, 437)
# Tag2Text generated tags: ['brain | image | medical']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 15
# Question: is there consolidation in the lungs?
# Image size: (762, 630)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 16
# Question: what type of image is this?
# Image size: (1024, 1030)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 17
# Question: what are these opacities anterior to the right kidney?
# Image size: (1024, 557)
# Tag2Text generated tags: ['brain | bone | image | picture | skull | show']
# Tag2Text generated caption: a mri image of a skull showing bones in the brain
# --------------------------------------------------
#
# Processing image 18
# Question: are the brain gyri atrophied?
# Image size: (296, 336)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 19
# Question: is the anatomy of the brain gyri affected?
# Image size: (323, 322)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 20
# Question: what is the medium density close to the anterior abdominal wall?
# Image size: (512, 512)
# Tag2Text generated tags: ['image | picture | show']
# Tag2Text generated caption: a radiograph showing a cataract in the abdomen
# --------------------------------------------------
#
# Processing image 21
# Question: is this an ap image?
# Image size: (1024, 1030)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 22
# Question: what is the plane of this image?
# Image size: (323, 322)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 23
# Question: is this a ct image?
# Image size: (843, 768)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 24
# Question: is there evidence of small bowel obstruction on this image?
# Image size: (1024, 1311)
# Tag2Text generated tags: ['bone | image | show']
# Tag2Text generated caption: a radiograph shows a bone with a large bump in the middle of the bone
# --------------------------------------------------
#
# Processing image 25
# Question: what type of image is this?
# Image size: (1024, 557)
# Tag2Text generated tags: ['brain | bone | image | picture | skull | show']
# Tag2Text generated caption: a mri image of a skull showing bones in the brain
# --------------------------------------------------
#
# Processing image 26
# Question: is there leakage of blood?
# Image size: (318, 391)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 27
# Question: is there herniation?
# Image size: (305, 427)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an mri image of a brain
# --------------------------------------------------
#
# Processing image 28
# Question: what bright white structures form an x?
# Image size: (341, 428)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 29
# Question: what are the bright white structures, almost forming an x"?"
# Image size: (341, 428)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 30
# Question: can you see the esophagus in this image?
# Image size: (1024, 645)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain shows a stroke
# --------------------------------------------------
#
# Processing image 31
# Question: is the esophagus visible?
# Image size: (1024, 645)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain shows a stroke
# --------------------------------------------------
#
# Processing image 32
# Question: is this supratentorial or infratentorial?
# Image size: (388, 542)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 33
# Question: is this modality safe for pregnant women?
# Image size: (1024, 1023)
# Tag2Text generated tags: ['figure | image | chest | patient']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph in the image
# --------------------------------------------------
#
# Processing image 34
# Question: can fluids be highlighted with this modality?
# Image size: (388, 542)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 35
# Question: is there small bowel thickening present?
# Image size: (1024, 1311)
# Tag2Text generated tags: ['bone | image | show']
# Tag2Text generated caption: a radiograph shows a bone with a large bump in the middle of the bone
# --------------------------------------------------
#
# Processing image 36
# Question: are the kidneys normal?
# Image size: (512, 512)
# Tag2Text generated tags: ['baby | brain | image | show | medical']
# Tag2Text generated caption: a medical image of the brain of a baby
# --------------------------------------------------
#
# Processing image 37
# Question: do the kidneys appear to be normal?
# Image size: (512, 512)
# Tag2Text generated tags: ['baby | brain | image | show | medical']
# Tag2Text generated caption: a medical image of the brain of a baby
# --------------------------------------------------
#
# Processing image 38
# Question: are the lateral ventricles visible?
# Image size: (599, 555)
# Tag2Text generated tags: ['brain | image | medical']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 39
# Question: can the lateral ventricles be seen?
# Image size: (599, 555)
# Tag2Text generated tags: ['brain | image | medical']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 40
# Question: what hypoattenuated tissue is between the abdominal wall and skin?
# Image size: (1024, 581)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 41
# Question: what is the dark structure underneath the skin?
# Image size: (1024, 581)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 42
# Question: does this mass likely represent a neoplastic process?
# Image size: (1024, 941)
# Tag2Text generated tags: ['image | show']
# Tag2Text generated caption: a ct scan of the abdomen showing the fertilisation of fertilisation of fertilisation of ferti
# --------------------------------------------------
#
# Processing image 43
# Question: is this a neoplastic process?
# Image size: (1024, 941)
# Tag2Text generated tags: ['image | show']
# Tag2Text generated caption: a ct scan of the abdomen showing the fertilisation of fertilisation of fertilisation of ferti
# --------------------------------------------------
#
# Processing image 44
# Question: is the vertebrae fractured?
# Image size: (1024, 642)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 45
# Question: is there a verterbral fracture?
# Image size: (1024, 642)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 46
# Question: was the patient positioned appropriately 	without tilting?
# Image size: (1024, 1286)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 47
# Question: can you evaluate a mediastinum in the shown image?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 48
# Question: is the mediastinum visualized?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 49
# Question: where is the tip of the line?
# Image size: (1024, 842)
# Tag2Text generated tags: ['image | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest
# --------------------------------------------------
#
# Processing image 50
# Question: where is the tip of the port-a-cath catheter located?
# Image size: (1024, 842)
# Tag2Text generated tags: ['image | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest
# --------------------------------------------------
#
# Processing image 51
# Question: do you see hylar lymphadenopathy in this image?
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph
# --------------------------------------------------
#
# Processing image 52
# Question: is there hylar lymphadenopathy?
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph
# --------------------------------------------------
#
# Processing image 53
# Question: is there a widened mediastinum?
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph
# --------------------------------------------------
#
# Processing image 54
# Question: is the mediastinum wider than normal?
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph
# --------------------------------------------------
#
# Processing image 55
# Question: is the heart enlarged?
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest | patient | person']
# Tag2Text generated caption: chest radiograph of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 56
# Question: is there cardiomegaly?
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest | patient | person']
# Tag2Text generated caption: chest radiograph of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 57
# Question: is the small bowel appropriately identified with gi contrast?
# Image size: (1024, 421)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 58
# Question: is there fluid in the lung?
# Image size: (1024, 1159)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest xray
# --------------------------------------------------
#
# Processing image 59
# Question: is this a pleural effusion
# Image size: (1024, 1159)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest xray
# --------------------------------------------------
#
# Processing image 60
# Question: is mass effect present?
# Image size: (337, 411)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 61
# Question: is there mass effect?
# Image size: (337, 411)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 62
# Question: how was this image taken
# Image size: (329, 434)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 63
# Question: is there a mass
# Image size: (1024, 1187)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 64
# Question: is a mass present in this xray?
# Image size: (1024, 1187)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 65
# Question: describe the pathology
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest | patient | person']
# Tag2Text generated caption: chest radiograph of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 66
# Question: what is the pathology?
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest | patient | person']
# Tag2Text generated caption: chest radiograph of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 67
# Question: what organ system is the pathology?
# Image size: (1024, 842)
# Tag2Text generated tags: ['figure | image | chest']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph
# --------------------------------------------------
#
# Processing image 68
# Question: is there a small bowel obstruction?
# Image size: (1024, 421)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 69
# Question: is there brain edema
# Image size: (555, 691)
# Tag2Text generated tags: ['brain | image | medical']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 70
# Question: is the brain swollen?
# Image size: (555, 691)
# Tag2Text generated tags: ['brain | image | medical']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 71
# Question: what is the location of the cavitary lesion
# Image size: (1024, 1248)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 72
# Question: where is the cavitary lesion located?
# Image size: (1024, 1248)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 73
# Question: are there increased vascular markings
# Image size: (925, 1125)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 74
# Question: are the vascular markings increased?
# Image size: (925, 1125)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 75
# Question: what plane is this film
# Image size: (630, 768)
# Tag2Text generated tags: ['figure | image | chest']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph
# --------------------------------------------------
#
# Processing image 76
# Question: what is the location of the mass?
# Image size: (766, 766)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 77
# Question: where is the mass located?
# Image size: (766, 766)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 78
# Question: the mass is found in which part of the pancreas?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | picture | show | medical']
# Tag2Text generated caption: a medical image of a ct scan of the brain
# --------------------------------------------------
#
# Processing image 79
# Question: are there hyper attenuating material along the aortic walls?
# Image size: (1024, 1105)
# Tag2Text generated tags: ['figure | image | show']
# Tag2Text generated caption: a ct scan of the abdomen showing a bone scan
# --------------------------------------------------
#
# Processing image 80
# Question: what type of mri sequence is displayed in this image?
# Image size: (766, 857)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 81
# Question: from what structure is the large hypodense mass emanating from?
# Image size: (1024, 1151)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 82
# Question: what lobe of the brain is the lesion located in?
# Image size: (634, 867)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 83
# Question: is this an mri?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | skull | show']
# Tag2Text generated caption: a ct scan of the brain shows a large, flat - cut section of the skull
# --------------------------------------------------
#
# Processing image 84
# Question: does this patient have a pneumothorax?
# Image size: (1024, 1310)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 85
# Question: in what plane was this image taken?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | skull | show']
# Tag2Text generated caption: a ct scan of the brain shows a large, flat - cut section of the skull
# --------------------------------------------------
#
# Processing image 86
# Question: is this an mri or a ct scan?
# Image size: (555, 675)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 87
# Question: can the optic nerve be visualized in this mri image?
# Image size: (766, 857)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 88
# Question: in which two ventricles can calcifications be seen on this ct scan?
# Image size: (320, 353)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 89
# Question: what part of the body is being imaged here?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a mri image of the brain
# --------------------------------------------------
#
# Processing image 90
# Question: are there calcifications present on the abdominal aorta?
# Image size: (1024, 1105)
# Tag2Text generated tags: ['figure | image | show']
# Tag2Text generated caption: a ct scan of the abdomen showing a bone scan
# --------------------------------------------------
#
# Processing image 91
# Question: does this patient have pneumomediastinum?
# Image size: (1023, 841)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 92
# Question: what abnormality is seen on the left side of the frontal lobe?
# Image size: (634, 867)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 93
# Question: is this a coronal view?
# Image size: (1024, 1304)
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: this image shows a ct scan of the brain
# --------------------------------------------------
#
# Processing image 94
# Question: are these normal kidney findings?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain showing the location of the reticular action
# --------------------------------------------------
#
# Processing image 95
# Question: diaphragm is elevated on which side?
# Image size: (1019, 1280)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 96
# Question: which side of the diaphragm is elevated?
# Image size: (1019, 1280)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 97
# Question: where does the l renal vein connect to
# Image size: (1024, 1291)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 98
# Question: where does the l renal vein drain into?
# Image size: (1024, 1291)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 99
# Question: does the lesion appear to be wedge-shaped?
# Image size: (415, 495)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 100
# Question: is the lesion wedge-shaped?
# Image size: (415, 495)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 101
# Question: does this patient have evidence of pneumoperitoneum?
# Image size: (512, 512)
# Tag2Text generated tags: ['image | dog']
# Tag2Text generated caption: a ct scan of a dog
# --------------------------------------------------
#
# Processing image 102
# Question: is the lesion on the left or right side of the brain?
# Image size: (415, 495)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 103
# Question: what side of the brain is a lesion on?
# Image size: (415, 495)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 104
# Question: what plane is this?
# Image size: (960, 720)
# Tag2Text generated tags: ['image']
# Tag2Text generated caption: a ct scan of a cat's right fetus
# --------------------------------------------------
#
# Processing image 105
# Question: where is there evidence of a pleural effusion?
# Image size: (996, 1128)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 106
# Question: where is the pleural effusion located?
# Image size: (996, 1128)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 107
# Question: is there an acute infarction?
# Image size: (415, 495)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 108
# Question: is this consistent with an acute infarction?
# Image size: (415, 495)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of a brain
# --------------------------------------------------
#
# Processing image 109
# Question: is this a ct?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain showing the location of the reticular action
# --------------------------------------------------
#
# Processing image 110
# Question: where are the acute infarcts?
# Image size: (444, 532)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 111
# Question: where do you see acute infarcts?
# Image size: (444, 532)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 112
# Question: is this an axial plane?
# Image size: (566, 555)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 113
# Question: is there evidence of air in the peritoneal cavity?
# Image size: (512, 512)
# Tag2Text generated tags: ['image | dog']
# Tag2Text generated caption: a ct scan of a dog
# --------------------------------------------------
#
# Processing image 114
# Question: is the trachea located normally?
# Image size: (996, 1128)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 115
# Question: is the trachea midline?
# Image size: (996, 1128)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 116
# Question: is this the axial plane?
# Image size: (768, 768)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 117
# Question: how would you measure the length of the kidneys?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain showing the location of the reticular action
# --------------------------------------------------
#
# Processing image 118
# Question: is this a ct of the abdomen?
# Image size: (910, 1138)
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: this image shows a normal mri of the brain
# --------------------------------------------------
#
# Processing image 119
# Question: what type of imaging modality is used to acquire the above image?
# Image size: (555, 640)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 120
# Question: the image is taken in what plane?
# Image size: (446, 438)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 121
# Question: what plane is the above image acquired in?
# Image size: (446, 438)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 122
# Question: what is the location of the lesion?
# Image size: (1024, 1245)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 123
# Question: where is the lesion located?
# Image size: (1024, 1245)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 124
# Question: is the cardiac silhouette less than half the diameter of the diaphragm?
# Image size: (1023, 841)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 125
# Question: how large is the mass in the right upper quadrant?
# Image size: (1024, 1157)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 126
# Question: size of the mass in the right upper quadrant?
# Image size: (1024, 1157)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 127
# Question: is the patient a female or male?
# Image size: (1024, 1286)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest xray
# --------------------------------------------------
#
# Processing image 128
# Question: what is the biological sex of the patient?
# Image size: (1024, 1286)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest xray
# --------------------------------------------------
#
# Processing image 129
# Question: is the heart enlarged?
# Image size: (1024, 846)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 130
# Question: is the heart abnormally large?
# Image size: (1024, 846)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 131
# Question: is this image showing the chest?
# Image size: (861, 913)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 132
# Question: what organ system is being imaged?
# Image size: (960, 720)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 133
# Question: the hemorrhage is adjacent to what structures?
# Image size: (256, 256)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain shows the location of the thalamus
# --------------------------------------------------
#
# Processing image 134
# Question: what structures are located near the hemorrhage shown?
# Image size: (256, 256)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain shows the location of the thalamus
# --------------------------------------------------
#
# Processing image 135
# Question: is the cardiac silhouette within normal size limits?
# Image size: (1023, 841)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 136
# Question: what major artery of the brain may be affected by the lesion seen in the above image?
# Image size: (555, 640)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 137
# Question: which major artery of the brain is affected by this lesion?
# Image size: (555, 640)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 138
# Question: evidence of hemorrhage in the kidneys?
# Image size: (689, 688)
# Tag2Text generated tags: ['image | show | medical']
# Tag2Text generated caption: a medical image of a ct scan of the abdomen
# --------------------------------------------------
#
# Processing image 139
# Question: is there any hemorrhage seen within the kidneys?
# Image size: (689, 688)
# Tag2Text generated tags: ['image | show | medical']
# Tag2Text generated caption: a medical image of a ct scan of the abdomen
# --------------------------------------------------
#
# Processing image 140
# Question: is this a t1 weighted mri?
# Image size: (256, 256)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain shows the location of the thalamus
# --------------------------------------------------
#
# Processing image 141
# Question: where are the brain lesions located?
# Image size: (256, 256)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a mri image of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 142
# Question: which hemisphere of the brain are the lesions located in?
# Image size: (256, 256)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a mri image of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 143
# Question: in which brain area is the lesion located?
# Image size: (555, 619)
# Tag2Text generated tags: ['image | medical']
# Tag2Text generated caption: a ct scan of the right sagittal x ray
# --------------------------------------------------
#
# Processing image 144
# Question: where is the lesion located?
# Image size: (555, 619)
# Tag2Text generated tags: ['image | medical']
# Tag2Text generated caption: a ct scan of the right sagittal x ray
# --------------------------------------------------
#
# Processing image 145
# Question: the tissue within the hyperattenuating ovoid mass adjacent to the ascending colon is similar in density to what tissue normally found?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | show | medical']
# Tag2Text generated caption: a medical image of a ct scan of the brain
# --------------------------------------------------
#
# Processing image 146
# Question: is there narrowing of the cardiac contour?
# Image size: (986, 1200)
# Tag2Text generated tags: ['figure | image | chest | patient']
# Tag2Text generated caption: a chest x ray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 147
# Question: the tissue in the hyperattenuating ovoid mass on the patient's right is similar density wise to what tissue that is normally found?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | show | medical']
# Tag2Text generated caption: a medical image of a ct scan of the brain
# --------------------------------------------------
#
# Processing image 148
# Question: the lesion seen in the image above is isointense to what object that is normally found in the brain?
# Image size: (555, 640)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 149
# Question: the lesion is isointense to what object normally found in the brain?
# Image size: (555, 640)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 150
# Question: is the heart enlarged?
# Image size: (1024, 1157)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 151
# Question: is the heart abnormally large?
# Image size: (1024, 1157)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 152
# Question: the condition in which a patient has enlarged ventricles as seen in this image?
# Image size: (960, 720)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 153
# Question: what is the condition in which the ventricles are enlarged as seen in this image?
# Image size: (960, 720)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 154
# Question: what organ system is visualized in the above image?
# Image size: (555, 640)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 155
# Question: how was this image taken?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | skull | show']
# Tag2Text generated caption: a ct scan of the brain showing a skull
# --------------------------------------------------
#
# Processing image 156
# Question: what imaging modality is used?
# Image size: (512, 512)
# Tag2Text generated tags: ['brain | image | skull | show']
# Tag2Text generated caption: a ct scan of the brain showing a skull
# --------------------------------------------------
#
# Processing image 157
# Question: is the cardiac silhouette small/stretched
# Image size: (986, 1200)
# Tag2Text generated tags: ['figure | image | chest | patient']
# Tag2Text generated caption: a chest x ray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 158
# Question: in which lobe do you see an abnormal mass in the above images?
# Image size: (1024, 1157)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 159
# Question: where is the abnormal mass located with respect to the lungs?
# Image size: (1024, 1157)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 160
# Question: what imaging modality was used to take this image?
# Image size: (1024, 1157)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 161
# Question: where is the abnormality?
# Image size: (910, 1138)
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: this image shows a normal mri of the brain
# --------------------------------------------------
#
# Processing image 162
# Question: what abnormality is present?
# Image size: (910, 1138)
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: this image shows a normal mri of the brain
# --------------------------------------------------
#
# Processing image 163
# Question: is free air present in this image?
# Image size: (512, 512)
# Tag2Text generated tags: ['baby | image | dog']
# Tag2Text generated caption: a ct scan of a baby in the abdomen
# --------------------------------------------------
#
# Processing image 164
# Question: is there free air in the abdomen?
# Image size: (512, 512)
# Tag2Text generated tags: ['baby | image | dog']
# Tag2Text generated caption: a ct scan of a baby in the abdomen
# --------------------------------------------------
#
# Processing image 165
# Question: are the ventricles enlarged?
# Image size: (378, 378)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 166
# Question: is the size of the ventricle abnormal?
# Image size: (378, 378)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 167
# Question: how is the patient positioned for this scan?
# Image size: (1024, 642)
# Tag2Text generated tags: ['brain | image | picture | show']
# Tag2Text generated caption: a mri of the brain showing the location of the thalamus
# --------------------------------------------------
#
# Processing image 168
# Question: is there evidence of pulmonary edema?
# Image size: (1024, 1286)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 169
# Question: what is the hypodensity in the liver?
# Image size: (512, 512)
# Tag2Text generated tags: ['baby | image | dog']
# Tag2Text generated caption: a ct scan of a baby in the abdomen
# --------------------------------------------------
#
# Processing image 170
# Question: is there a hypodense mass in the liver
# Image size: (512, 512)
# Tag2Text generated tags: ['baby | image | dog']
# Tag2Text generated caption: a ct scan of a baby in the abdomen
# --------------------------------------------------
#
# Processing image 171
# Question: is this patient male or female?
# Image size: (1024, 1023)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest x ray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 172
# Question: what is the patient's gender?
# Image size: (1024, 1023)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest x ray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 173
# Question: is the trachea normal?
# Image size: (739, 942)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 174
# Question: is the trachea midline?
# Image size: (739, 942)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 175
# Question: is there a pneumothorax present?
# Image size: (1024, 870)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest xray
# --------------------------------------------------
#
# Processing image 176
# Question: is there free air in the thorax?
# Image size: (1024, 870)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest xray
# --------------------------------------------------
#
# Processing image 177
# Question: what is located immediately inferior to the right hemidiaphragm?
# Image size: (899, 925)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# ...
# Tag2Text generated caption: a ct scan of the brain shows a stroke
# --------------------------------------------------
#
# Processing image 391
# Question: is there cardiomegaly present?
# Image size: (800, 907)
# Tag2Text generated tags: ['chest | patient | rib']
# Tag2Text generated caption: a chest xray of a patient with a broken right rib
# --------------------------------------------------
#
# Processing image 392
# Question: is the image of the gastrointestinal system?
# Image size: (512, 512)
# Tag2Text generated tags: ['image | picture | show']
# Tag2Text generated caption: a picture of a ct scan showing an inflamed lung
# --------------------------------------------------
#
# Processing image 393
# Question: which plane is this image taken?
# Image size: (1024, 1295)
# Tag2Text generated tags: ['figure | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 394
# Question: are there multiple or just 1 metastatic focus?
# Image size: (1024, 1310)
# Tag2Text generated tags: ['brain | image | picture | show']
# Tag2Text generated caption: a ct scan of the brain shows a stroke
# --------------------------------------------------
#
# Processing image 395
# Question: how many lesions are in the spleen?
# Image size: (1024, 1310)
# Tag2Text generated tags: ['brain | image | picture | show']
# Tag2Text generated caption: a ct scan of the brain shows a stroke
# --------------------------------------------------
#
# Processing image 396
# Question: is there cardiomyopathy?
# Image size: (1024, 1291)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 397
# Question: what is abnormal about the pancreas?
# Image size: (512, 385)
# Tag2Text generated tags: ['bone | image']
# Tag2Text generated caption: a radiograph of the right sagittal x ray
# --------------------------------------------------
#
# Processing image 398
# Question: why is the pancreas abnormal?
# Image size: (512, 385)
# Tag2Text generated tags: ['bone | image']
# Tag2Text generated caption: a radiograph of the right sagittal x ray
# --------------------------------------------------
#
# Processing image 399
# Question: what abnormalities are in the lung apices?
# Image size: (1024, 1304)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 400
# Question: what is seen in the lung apices?
# Image size: (1024, 1304)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 401
# Question: are the lungs normal?
# Image size: (1024, 1295)
# Tag2Text generated tags: ['figure | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 402
# Question: is the image study normal?
# Image size: (1024, 1295)
# Tag2Text generated tags: ['figure | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 403
# Question: how would you describe the abnormalities
# Image size: (555, 692)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 404
# Question: are the lesions ring-enhancing?
# Image size: (555, 692)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 405
# Question: what lobe is the lesion located in?
# Image size: (555, 759)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 406
# Question: where is the abnormality located?
# Image size: (555, 759)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 407
# Question: are >12 ribs present in the image?
# Image size: (986, 1200)
# Tag2Text generated tags: ['figure | image | chest | patient']
# Tag2Text generated caption: a chest x ray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 408
# Question: how would you describe the aortopulmonary window?
# Image size: (1024, 1053)
# Tag2Text generated tags: ['figure | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 409
# Question: what characteristic finding do you see in the aortopulmonary window?
# Image size: (1024, 1053)
# Tag2Text generated tags: ['figure | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 410
# Question: which sign do you see in the aortopulmonary window in this image?
# Image size: (1024, 1053)
# Tag2Text generated tags: ['figure | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 411
# Question: where is the diffuse pleural thickening?
# Image size: (1024, 1295)
# Tag2Text generated tags: ['figure | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 412
# Question: which lung is abnormal?
# Image size: (1024, 1295)
# Tag2Text generated tags: ['figure | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 413
# Question: is the mass calcified?
# Image size: (1024, 642)
# Tag2Text generated tags: ['brain | image | skull | show']
# Tag2Text generated caption: a ct scan of the skull shows a missing brain
# --------------------------------------------------
#
# Processing image 414
# Question: does this look like a healthy liver?
# Image size: (512, 512)
# Tag2Text generated tags: ['image | picture | show']
# Tag2Text generated caption: a picture of a ct scan showing an inflamed lung
# --------------------------------------------------
#
# Processing image 415
# Question: is the liver normal?
# Image size: (512, 512)
# Tag2Text generated tags: ['image | picture | show']
# Tag2Text generated caption: a picture of a ct scan showing an inflamed lung
# --------------------------------------------------
#
# Processing image 416
# Question: is this a normal x ray?
# Image size: (1024, 1090)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest xray
# --------------------------------------------------
#
# Processing image 417
# Question: is the right hemidiaphragm normal?
# Image size: (1024, 1090)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest xray
# --------------------------------------------------
#
# Processing image 418
# Question: does this represent adequate inspiratory effort?
# Image size: (986, 1200)
# Tag2Text generated tags: ['figure | image | chest | patient']
# Tag2Text generated caption: a chest x ray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 419
# Question: what kind of image is this?
# Image size: (1024, 1304)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 420
# Question: is this in a coronal plane?
# Image size: (1023, 1161)
# Tag2Text generated tags: ['brain | image | picture | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 421
# Question: is the surrounding phlegmon normal?
# Image size: (512, 385)
# Tag2Text generated tags: ['bone | image']
# Tag2Text generated caption: a radiograph of the right sagittal x ray
# --------------------------------------------------
#
# Processing image 422
# Question: is the fat surrounding the pancreas normal?
# Image size: (512, 385)
# Tag2Text generated tags: ['bone | image']
# Tag2Text generated caption: a radiograph of the right sagittal x ray
# --------------------------------------------------
#
# Processing image 423
# Question: are lung markings present in the entire thoracic cavity?
# Image size: (1024, 1056)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 424
# Question: is there a pneumothorax present?
# Image size: (1024, 1056)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
#
# Processing image 425
# Question: is there more than one organ system present in the image?
# Image size: (777, 686)
# Tag2Text generated tags: ['brain | image']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 426
# Question: how many instances of intussusception are in the image?
# Image size: (512, 512)
# Tag2Text generated tags: ['image | child | show']
# Tag2Text generated caption: a radiograph of a child with an inflamed lung
# --------------------------------------------------
#
# Processing image 427
# Question: is there more than one intussusception present?
# Image size: (512, 512)
# Tag2Text generated tags: ['image | child | show']
# Tag2Text generated caption: a radiograph of a child with an inflamed lung
# --------------------------------------------------
#
# Processing image 428
# Question: which side is more clearly visualized?
# Image size: (1024, 1309)
# Tag2Text generated tags: ['image | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 429
# Question: is there a rib fracture?
# Image size: (1024, 1024)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 430
# Question: which lung is clearer?
# Image size: (1024, 1309)
# Tag2Text generated tags: ['image | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 431
# Question: is the diaphragm clearly visualized on both sides of the thorax?
# Image size: (673, 827)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 432
# Question: is the diaphragm obscured?
# Image size: (673, 827)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 433
# Question: is the heart wider than more than half the width of the thorax?
# Image size: (419, 512)
# Tag2Text generated tags: ['chest | patient | medical']
# Tag2Text generated caption: a chest xray of a patient with a chest x ray
# --------------------------------------------------
#
# Processing image 434
# Question: how wide is the heart compared to the thorax?
# Image size: (419, 512)
# Tag2Text generated tags: ['chest | patient | medical']
# Tag2Text generated caption: a chest xray of a patient with a chest x ray
# --------------------------------------------------
#
# Processing image 435
# Question: is there evidence of subdiaphragmatic free air on the left?
# Image size: (420, 512)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest x ray
# --------------------------------------------------
#
# Processing image 436
# Question: is the free air under the left hemidiaphragm pathologic?
# Image size: (420, 512)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest x ray
# --------------------------------------------------
#
# Processing image 437
# Question: is the gallbladder present?
# Image size: (1024, 656)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 438
# Question: what is the dense mass visualized in the liver?
# Image size: (1024, 656)
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: a ct scan of the brain
# --------------------------------------------------
#
# Processing image 439
# Question: where is free air trapped subcutaneously in this image?
# Image size: (910, 1138)
# Tag2Text generated tags: ['figure | image | chest']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph
# --------------------------------------------------
#
# Processing image 440
# Question: is there evidence of any fractures of the ribs?
# Image size: (1024, 1024)
# Tag2Text generated tags: ['chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 441
# Question: is there free air in the supraclavicular fossae?
# Image size: (910, 1138)
# Tag2Text generated tags: ['figure | image | chest']
# Tag2Text generated caption: a chest radiograph showing a chest radiograph
# --------------------------------------------------
#
# Processing image 442
# Question: where is the ascending colon?
# Image size: (1024, 654)
# Tag2Text generated tags: ['image | show']
# Tag2Text generated caption: a ct scan of the heart
# --------------------------------------------------
#
# Processing image 443
# Question: what structure lies directly posterior to the appendix in this image?
# Image size: (1024, 654)
# Tag2Text generated tags: ['image | show']
# Tag2Text generated caption: a ct scan of the heart
# --------------------------------------------------
#
# Processing image 444
# Question: are the borders of the heart clearly visualized?
# Image size: (1024, 1307)
# Tag2Text generated tags: ['figure | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a chest radiograph
# --------------------------------------------------
#
# Processing image 445
# Question: where is the subcutaneous air collection?
# Image size: (1024, 1309)
# Tag2Text generated tags: ['image | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 446
# Question: is there subcutaneous air present in the right neck?
# Image size: (1024, 1309)
# Tag2Text generated tags: ['image | chest']
# Tag2Text generated caption: a chest xray of a person's chest
# --------------------------------------------------
#
# Processing image 447
# Question: is this image taken above the diaphragm?
# Image size: (512, 512)
# Tag2Text generated tags: ['bone']
# Tag2Text generated caption: a ct scan of the right hip bone
# --------------------------------------------------
#
# Processing image 448
# Question: what is in the left apex?
# Image size: (987, 1200)
# Tag2Text generated tags: ['image | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a broken right lung
# --------------------------------------------------
#
# Processing image 449
# Question: is a pneumothorax present in the left apex?
# Image size: (987, 1200)
# Tag2Text generated tags: ['image | chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a broken right lung
# --------------------------------------------------
#
# Processing image 450
# Question: where is the lesion located?
# Image size: (867, 979)
# Tag2Text generated tags: ['chest | patient']
# Tag2Text generated caption: a chest xray of a patient with a heart attack
# --------------------------------------------------
# Processing complete. Results saved to /content/drive/MyDrive/PhD/Research1/RADdataset/processed_data.json

# %%
#===tag2text with slake========

# %%
from google.colab import drive
drive.mount('/content/drive')#
import io
import sys
import os
import json
import torch
from PIL import Image
import pandas as pd
from tqdm.notebook import tqdm
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sys.path.append('/content/drive/MyDrive/PhD/Research1/recognize-anything-main')
try:

    import importlib
    if not importlib.util.find_spec("fairscale"):
        print("Installing fairscale...")
        # !pip install fairscale
    if not importlib.util.find_spec("timm"):
        print("Installing timm...")
        # !pip install timm
    if not importlib.util.find_spec("transformers"):
        print("Installing transformers...")
        # !pip install transformers

    from ram.models import tag2text
    from ram import get_transform
    print("Successfully imported tag2text from Google Drive")
except ImportError as e:
    print(f"Error importing from Google Drive: {e}")
    print("Falling back to cloning the repository in Colab's local filesystem")
    # !git clone https://github.com/xinyu1205/recognize-anything.git /content/recognize-anything
    # %cd /content/recognize-anything

    # !pip install fairscale timm transformers
    # !pip install -e .
    # %cd /content
    sys.path.append('/content/recognize-anything')
    from ram.models import tag2text
    from ram import get_transform


global_models = {}
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/hub.py:4: FutureWarning: Importing from timm.models.hub is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Successfully imported tag2text from Google Drive

# %%
def load_models():
    if 'tag2text' not in global_models:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {device}")


        delete_tag_index = [127, 2961, 3351, 3265, 3338, 3355, 3359]
        global_models['tag2text'] = tag2text(pretrained="/content/drive/MyDrive/PhD/Research1/recognize-anything-main/pretrained/tag2text_swin_14m.pth",
                                           image_size=384,
                                           vit='swin_b',
                                           delete_tag_index=delete_tag_index)
        global_models['tag2text'].threshold = 0.68
        global_models['tag2text'].eval()
        global_models['tag2text'] = global_models['tag2text'].to(device)
        print("Tag2Text model loaded successfully")


        global_models['transform'] = get_transform(image_size=384)

def process_image(image_path):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    try:
        print(f"Loading image from: {image_path}")

        if not os.path.exists(image_path):
            print(f"ERROR: Image file not found: {image_path}")
            return [], "Error: Image file not found"


        image = Image.open(image_path).convert('RGB')
        print(f"Image successfully loaded. Size: {image.size}")


        print("Applying image transformation...")
        image_tensor = global_models['transform'](image).unsqueeze(0).to(device)
        print(f"Image transformed to tensor of shape: {image_tensor.shape}")


        print("Running Tag2Text model inference...")
        with torch.no_grad():
            result = global_models['tag2text'].generate(image_tensor, return_tag_predict=True)
        print("Tag2Text inference completed")

        if isinstance(result, tuple) and len(result) == 2:
            captions, tags = result
            caption = captions[0] if captions else "No caption generated"
            print(f"Got caption: {caption}")
        else:
            tags = result[0] if isinstance(result, list) else "No tags generated"
            caption = "No caption generated"
            print("No caption in result, only tags")


        if isinstance(tags, str):
            tags = tags.split('|')

        print(f"Tag2Text generated tags: {tags}")
        print(f"Tag2Text generated caption: {caption}")

        return tags, caption
    except Exception as e:
        import traceback
        print(f"Error processing image: {e}")
        print(traceback.format_exc())
        return [], f"Error generating caption: {str(e)}"

def main():

    load_models()


    slake_base_dir = '/content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0'
    json_path = os.path.join(slake_base_dir, 'test.json')
    output_dir = '/content/drive/MyDrive/PhD/Research1/output'
    output_json = os.path.join(output_dir, 'slake_tag2text_results.json')


    os.makedirs(output_dir, exist_ok=True)


    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)


    english_samples = [item for item in data if item.get('q_lang') == 'en']
    print(f"Loaded {len(english_samples)} English samples from test.json")

    results = []


    temp_output_json = os.path.join(output_dir, 'slake_tag2text_results_temp.json')


    for idx, sample in tqdm(enumerate(english_samples), total=len(english_samples), desc="Processing images"):
        img_name = sample.get('img_name', '')
        img_id = sample.get('img_id', '')
        question = sample.get('question', '')
        answer = sample.get('answer', '')
        modality = sample.get('modality', '')


        img_path = os.path.join(slake_base_dir, 'imgs', img_name)

        print(f"\nProcessing image {idx} (ID: {img_id})")
        print(f"Image path: {img_path}")
        print(f"Question: {question}")
        print(f"Modality: {modality}")

        try:

            if not os.path.exists(img_path):
                print(f"WARNING: Image file not found at {img_path}")

                alternative_paths = [
                    os.path.join(slake_base_dir, 'img', img_name),
                    os.path.join(slake_base_dir, 'images', img_name)
                ]
                for alt_path in alternative_paths:
                    if os.path.exists(alt_path):
                        img_path = alt_path
                        print(f"Found image at alternative path: {img_path}")
                        break


            tags, tag2text_caption = process_image(img_path)


            result = {
                "id": idx,
                "img_id": img_id,
                "img_name": img_name,
                "question": question,
                "original_answer": answer,
                "modality": modality,
                "tag2text_caption": tag2text_caption,
                "tags": tags,
                "blip3_caption": None
            }
            results.append(result)
        except Exception as e:
            import traceback
            print(f"Error processing sample {idx}, image {img_name}: {e}")
            print(traceback.format_exc())

            results.append({
                "id": idx,
                "img_id": img_id,
                "img_name": img_name,
                "question": question,
                "original_answer": answer,
                "modality": modality,
                "tag2text_caption": f"Error generating caption: {str(e)}",
                "tags": [],
                "blip3_caption": None
            })


        if (idx + 1) % 10 == 0:
            try:
                with open(temp_output_json, 'w') as f:
                    json.dump(results, f, indent=2)
                print(f"Temporary results saved to {temp_output_json} after processing {idx+1} samples")
            except Exception as save_error:
                print(f"Error saving temporary results: {save_error}")

        print("-" * 50)


    try:
        with open(output_json, 'w') as f:
            json.dump(results, f, indent=2)
        print(f"Processing complete. Results saved to {output_json}")
    except Exception as save_error:
        print(f"Error saving final results: {save_error}")

        backup_output = os.path.join('/content', 'slake_tag2text_results_backup.json')
        with open(backup_output, 'w') as f:
            json.dump(results, f, indent=2)
        print(f"Results saved to backup location: {backup_output}")


if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# BertLMHeadModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# /encoder/layer/0/crossattention/self/query is tied
# /encoder/layer/0/crossattention/self/key is tied
# /encoder/layer/0/crossattention/self/value is tied
# /encoder/layer/0/crossattention/output/dense is tied
# /encoder/layer/0/crossattention/output/LayerNorm is tied
# /encoder/layer/0/intermediate/dense is tied
# /encoder/layer/0/output/dense is tied
# /encoder/layer/0/output/LayerNorm is tied
# /encoder/layer/1/crossattention/self/query is tied
# /encoder/layer/1/crossattention/self/key is tied
# /encoder/layer/1/crossattention/self/value is tied
# /encoder/layer/1/crossattention/output/dense is tied
# /encoder/layer/1/crossattention/output/LayerNorm is tied
# /encoder/layer/1/intermediate/dense is tied
# /encoder/layer/1/output/dense is tied
# /encoder/layer/1/output/LayerNorm is tied
# --------------
# /content/drive/MyDrive/PhD/Research1/recognize-anything-main/pretrained/tag2text_swin_14m.pth
# --------------
# load checkpoint from /content/drive/MyDrive/PhD/Research1/recognize-anything-main/pretrained/tag2text_swin_14m.pth
# vit: swin_b
# Tag2Text model loaded successfully
# Loaded 1061 English samples from test.json
# Processing images:   0%|          | 0/1061 [00:00<?, ?it/s]
# 流式输出内容被截断，只能显示最后 5000 行内容。
# --------------------------------------------------
#
# Processing image 730 (ID: 471)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab471/source.jpg
# Question: Where is the brain tumor?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab471/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of the human brain
# Tag2Text generated tags: ['brain | figure | image | photo']
# Tag2Text generated caption: an image of the human brain
# --------------------------------------------------
#
# Processing image 731 (ID: 471)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab471/source.jpg
# Question: What is the organ system visualized?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab471/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of the human brain
# Tag2Text generated tags: ['brain | figure | image | photo']
# Tag2Text generated caption: an image of the human brain
# --------------------------------------------------
#
# Processing image 732 (ID: 471)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab471/source.jpg
# Question: Is this image normal?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab471/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of the human brain
# Tag2Text generated tags: ['brain | figure | image | photo']
# Tag2Text generated caption: an image of the human brain
# --------------------------------------------------
#
# Processing image 733 (ID: 471)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab471/source.jpg
# Question: How to prevent the occurrence of the disease on the upper left lobe of brain in this image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab471/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of the human brain
# Tag2Text generated tags: ['brain | figure | image | photo']
# Tag2Text generated caption: an image of the human brain
# --------------------------------------------------
#
# Processing image 734 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: What imaging modality was used?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 735 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: Which kind of weighting is this image generated with, t1 or t2?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 736 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: Is this a transverse section?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 737 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: Which part of the body does this image belong to?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 738 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: Where is the brain tumor?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 739 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: Is this a study of the neck?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# Temporary results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results_temp.json after processing 740 samples
# --------------------------------------------------
#
# Processing image 740 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: What disease is/are shown on the upper right of brain?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 741 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: Is the abnormality hyperdense or hypodense?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 742 (ID: 473)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Question: What kind of symptoms will the disease on the upper right lobe of brain in the picture bring to the patient?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab473/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 743 (ID: 474)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Question: How was this image taken?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 744 (ID: 474)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Question: Is this a T1 weighted or T2 weighted MRI image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 745 (ID: 474)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Question: Is this a coronal section?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 746 (ID: 474)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Question: Do the organs in the image exist in the abdomen?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 747 (ID: 474)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Question: Where is the brain tumor?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 748 (ID: 474)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Question: Which organ system is imaged?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 749 (ID: 474)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Question: Is the brain abnormal?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# Temporary results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results_temp.json after processing 750 samples
# --------------------------------------------------
#
# Processing image 750 (ID: 474)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Question: How to prevent the occurrence of the disease on the upper right lobe of brain in this image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab474/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a ct scan of the human brain
# Tag2Text generated tags: ['brain | figure | image']
# Tag2Text generated caption: a ct scan of the human brain
# --------------------------------------------------
#
# Processing image 751 (ID: 483)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Question: Is this image taken via MRI?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a brain with a ct scan
# Tag2Text generated tags: ['brain | image | picture | photo | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 752 (ID: 483)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Question: What is the mr weighting in this image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a brain with a ct scan
# Tag2Text generated tags: ['brain | image | picture | photo | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 753 (ID: 483)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Question: What scanning plane does this image belong to?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a brain with a ct scan
# Tag2Text generated tags: ['brain | image | picture | photo | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 754 (ID: 483)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Question: Where does the image represent in the body?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a brain with a ct scan
# Tag2Text generated tags: ['brain | image | picture | photo | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 755 (ID: 483)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Question: Which lobe is abnormal,left or right?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a brain with a ct scan
# Tag2Text generated tags: ['brain | image | picture | photo | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 756 (ID: 483)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Question: Is this a study of the head?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a brain with a ct scan
# Tag2Text generated tags: ['brain | image | picture | photo | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 757 (ID: 483)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Question: What diseases are included in the picture?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a brain with a ct scan
# Tag2Text generated tags: ['brain | image | picture | photo | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 758 (ID: 483)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Question: How much damage will be caused to the body taking such an image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab483/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a brain with a ct scan
# Tag2Text generated tags: ['brain | image | picture | photo | show']
# Tag2Text generated caption: a picture of a brain with a ct scan
# --------------------------------------------------
#
# Processing image 759 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: What modality is used to take this image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# Temporary results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results_temp.json after processing 760 samples
# --------------------------------------------------
#
# Processing image 760 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: Which part of the body does this image belong to?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# --------------------------------------------------
#
# Processing image 761 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: What is the mr weighting in this image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# --------------------------------------------------
#
# Processing image 762 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: What is the main organ in the image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# --------------------------------------------------
#
# Processing image 763 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: What is the largest organ in the picture?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# --------------------------------------------------
#
# Processing image 764 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: Does the picture contain brian?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# --------------------------------------------------
#
# Processing image 765 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: What diseases are included in the picture?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# --------------------------------------------------
#
# Processing image 766 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: Does the brain look abnormal?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# --------------------------------------------------
#
# Processing image 767 (ID: 49)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Question: Where is/are the abnormality located?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab49/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an mri image of a human brain
# Tag2Text generated tags: ['brain | figure | image | show']
# Tag2Text generated caption: an mri image of a human brain
# --------------------------------------------------
#
# Processing image 768 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: Is this a X-Ray?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# --------------------------------------------------
#
# Processing image 769 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: Which kind of weighting is this image generated with, t1 or t2?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# Temporary results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results_temp.json after processing 770 samples
# --------------------------------------------------
#
# Processing image 770 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: Is this a coronal plane?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# --------------------------------------------------
#
# Processing image 771 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: Which part of the body does this image belong to?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# --------------------------------------------------
#
# Processing image 772 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: Where is/are the abnormality located?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# --------------------------------------------------
#
# Processing image 773 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: What organ system is pictured?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# --------------------------------------------------
#
# Processing image 774 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: Is/Are there abnormalities in the patient's left brain lobe?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# --------------------------------------------------
#
# Processing image 775 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: How many kinds of abnormalities are there in this image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# --------------------------------------------------
#
# Processing image 776 (ID: 495)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Question: How much damage will be caused to the body taking such an image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab495/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: an image of a human brain in the dark
# Tag2Text generated tags: ['brain | image | show']
# Tag2Text generated caption: an image of a human brain in the dark
# --------------------------------------------------
#
# Processing image 777 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: Is this a CT scan?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# --------------------------------------------------
#
# Processing image 778 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: What is the mr weighting in this image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# --------------------------------------------------
#
# Processing image 779 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: Is this sagittal plane?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# Temporary results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results_temp.json after processing 780 samples
# --------------------------------------------------
#
# Processing image 780 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: Do the organs in the image exist in the pelvic cavity?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# --------------------------------------------------
#
# Processing image 781 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: Where are the abnormalities in this image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# --------------------------------------------------
#
# Processing image 782 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: Which organ system is imaged?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# --------------------------------------------------
#
# Processing image 783 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: What diseases are included in the picture?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# --------------------------------------------------
#
# Processing image 784 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: Is the brain enhancing tumor hyperdense or hypodense?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# --------------------------------------------------
#
# Processing image 785 (ID: 498)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Question: What kind of symptoms will the disease on the left lobe of brain in the picture bring to the patient?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab498/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: the image shows a normal brain with a ct scan
# Tag2Text generated tags: ['brain | figure | image | photo | show']
# Tag2Text generated caption: the image shows a normal brain with a ct scan
# --------------------------------------------------
#
# Processing image 786 (ID: 506)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Question: Is this image taken via CT?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a flower in black and white
# Tag2Text generated tags: ['brain | black | image | flower | white | picture | photo | black']
# Tag2Text generated caption: a picture of a flower in black and white
# --------------------------------------------------
#
# Processing image 787 (ID: 506)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Question: Which kind of weighting is this image generated with, t1 or t2?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a flower in black and white
# Tag2Text generated tags: ['brain | black | image | flower | white | picture | photo | black']
# Tag2Text generated caption: a picture of a flower in black and white
# --------------------------------------------------
#
# Processing image 788 (ID: 506)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Question: In what plane is this image scanned?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a flower in black and white
# Tag2Text generated tags: ['brain | black | image | flower | white | picture | photo | black']
# Tag2Text generated caption: a picture of a flower in black and white
# --------------------------------------------------
#
# Processing image 789 (ID: 506)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Question: Which part of the human body is the organ located in the image?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a flower in black and white
# Tag2Text generated tags: ['brain | black | image | flower | white | picture | photo | black']
# Tag2Text generated caption: a picture of a flower in black and white
# Temporary results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results_temp.json after processing 790 samples
# --------------------------------------------------
#
# Processing image 790 (ID: 506)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Question: Where is the brain tumor located?
# Modality: MRI
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Image successfully loaded. Size: (240, 240)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a picture of a flower in black and white
# Tag2Text generated tags: ['brain | black | image | flower | white | picture | photo | black']
# Tag2Text generated caption: a picture of a flower in black and white
# --------------------------------------------------
#
# Processing image 791 (ID: 506)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab506/source.jpg
# Question: Is this a study of the chest?
# Modality: MRI
# ...
# --------------------------------------------------
#
# Processing image 1041 (ID: 85)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Question: Does the picture contain liver?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white drawing of a cat and its baby on a plate
# Tag2Text generated tags: ['baby | image | drawing | cat | illustration | plate | picture | show | black']
# Tag2Text generated caption: a black and white drawing of a cat and its baby on a plate
# --------------------------------------------------
#
# Processing image 1042 (ID: 85)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Question: Does the picture contain lung?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white drawing of a cat and its baby on a plate
# Tag2Text generated tags: ['baby | image | drawing | cat | illustration | plate | picture | show | black']
# Tag2Text generated caption: a black and white drawing of a cat and its baby on a plate
# --------------------------------------------------
#
# Processing image 1043 (ID: 85)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Question: Does the picture contain heart?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white drawing of a cat and its baby on a plate
# Tag2Text generated tags: ['baby | image | drawing | cat | illustration | plate | picture | show | black']
# Tag2Text generated caption: a black and white drawing of a cat and its baby on a plate
# --------------------------------------------------
#
# Processing image 1044 (ID: 85)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Question: Does the lung look healthy?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white drawing of a cat and its baby on a plate
# Tag2Text generated tags: ['baby | image | drawing | cat | illustration | plate | picture | show | black']
# Tag2Text generated caption: a black and white drawing of a cat and its baby on a plate
# --------------------------------------------------
#
# Processing image 1045 (ID: 85)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Question: Which is the biggest in this image,lung,liver or heart?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab85/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white drawing of a cat and its baby on a plate
# Tag2Text generated tags: ['baby | image | drawing | cat | illustration | plate | picture | show | black']
# Tag2Text generated caption: a black and white drawing of a cat and its baby on a plate
# --------------------------------------------------
#
# Processing image 1046 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: What modality is used to take this image?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# --------------------------------------------------
#
# Processing image 1047 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: Which part of the body does this image belong to?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# --------------------------------------------------
#
# Processing image 1048 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: What is the main organ in the image?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# --------------------------------------------------
#
# Processing image 1049 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: What is the largest organ in the picture?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# Temporary results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results_temp.json after processing 1050 samples
# --------------------------------------------------
#
# Processing image 1050 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: Does the picture contain liver?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# --------------------------------------------------
#
# Processing image 1051 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: Does the picture contain lung?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# --------------------------------------------------
#
# Processing image 1052 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: Does the picture contain heart?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# --------------------------------------------------
#
# Processing image 1053 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: Is the lung healthy?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# --------------------------------------------------
#
# Processing image 1054 (ID: 90)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Question: Which is the biggest in this image,lung,liver or heart?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab90/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white illustration of a cross section of the abdomen
# Tag2Text generated tags: ['image | illustration | show | black']
# Tag2Text generated caption: a black and white illustration of a cross section of the abdomen
# --------------------------------------------------
#
# Processing image 1055 (ID: 93)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Question: What modality is used to take this image?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white image of a ct scan
# Tag2Text generated tags: ['brain | image | show | black']
# Tag2Text generated caption: a black and white image of a ct scan
# --------------------------------------------------
#
# Processing image 1056 (ID: 93)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Question: Which part of the body does this image belong to?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white image of a ct scan
# Tag2Text generated tags: ['brain | image | show | black']
# Tag2Text generated caption: a black and white image of a ct scan
# --------------------------------------------------
#
# Processing image 1057 (ID: 93)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Question: What is the main organ in the image?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white image of a ct scan
# Tag2Text generated tags: ['brain | image | show | black']
# Tag2Text generated caption: a black and white image of a ct scan
# --------------------------------------------------
#
# Processing image 1058 (ID: 93)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Question: Does the picture contain liver?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white image of a ct scan
# Tag2Text generated tags: ['brain | image | show | black']
# Tag2Text generated caption: a black and white image of a ct scan
# --------------------------------------------------
#
# Processing image 1059 (ID: 93)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Question: Does the picture contain lung?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white image of a ct scan
# Tag2Text generated tags: ['brain | image | show | black']
# Tag2Text generated caption: a black and white image of a ct scan
# Temporary results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results_temp.json after processing 1060 samples
# --------------------------------------------------
#
# Processing image 1060 (ID: 93)
# Image path: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Question: Does the picture contain heart?
# Modality: CT
# Loading image from: /content/drive/MyDrive/PhD/Research1/slakedataset/Slake1.0/imgs/xmlab93/source.jpg
# Image successfully loaded. Size: (512, 512)
# Applying image transformation...
# Image transformed to tensor of shape: torch.Size([1, 3, 384, 384])
# Running Tag2Text model inference...
# Tag2Text inference completed
# Got caption: a black and white image of a ct scan
# Tag2Text generated tags: ['brain | image | show | black']
# Tag2Text generated caption: a black and white image of a ct scan
# --------------------------------------------------
# Processing complete. Results saved to /content/drive/MyDrive/PhD/Research1/output/slake_tag2text_results.json
